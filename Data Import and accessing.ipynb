# %%
import pandas as pd

data=pd.read_csv('test2.csv')
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
data1=data.groupby('Education')
data1.size() #works almost same as value counts but only sorts the data better
# Out:
# Education
# Graduate        283
# Not Graduate     84
# dtype: int64

# %%
data2= data.sort_values('LoanAmount')
data2 #sorts the data numerically
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 21   LP001124  Female      No         3+  Not Graduate            No
# 232  LP002306    Male     Yes          0      Graduate            No
# 53   LP001298    Male     Yes          2      Graduate            No
# 334  LP002849    Male     Yes          0      Graduate            No
# 323  LP002791    Male      No          1      Graduate           NaN
# ..        ...     ...     ...        ...           ...           ...
# 78   LP001415    Male     Yes          1      Graduate            No
# 101  LP001542  Female     Yes          0      Graduate            No
# 188  LP002057    Male     Yes          0  Not Graduate            No
# 247  LP002360    Male     Yes        NaN      Graduate            No
# 289  LP002593    Male     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Accessing Funcions:

# %%
# Accessing by row:
data3= data[['Loan_ID', 'Gender', 'Education']]
data3
# Out:
#       Loan_ID Gender     Education
# 0    LP001015   Male      Graduate
# 1    LP001022   Male      Graduate
# 2    LP001031   Male      Graduate
# 3    LP001035   Male      Graduate
# 4    LP001051   Male  Not Graduate
# ..        ...    ...           ...
# 362  LP002971   Male  Not Graduate
# 363  LP002975   Male      Graduate
# 364  LP002980   Male      Graduate
# 365  LP002986   Male      Graduate
# 366  LP002989   Male      Graduate
#
# [367 rows x 3 columns]

# %%
#Accessing by Columns (using index):
data4=data.loc[5:10]
data4
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5   LP001054    Male     Yes          0  Not Graduate           Yes
# 6   LP001055  Female      No          1  Not Graduate            No
# 7   LP001056    Male     Yes          2  Not Graduate            No
# 8   LP001059    Male     Yes          2      Graduate           NaN
# 9   LP001067    Male      No          0  Not Graduate            No
# 10  LP001078    Male      No          0  Not Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5              2165               3422       152.0             360.0
# 6              2226                  0        59.0             360.0
# 7              3881                  0       147.0             360.0
# 8             13633                  0       280.0             240.0
# 9              2400               2400       123.0             360.0
# 10             3091                  0        90.0             360.0
#
# ...

# %%
#Accessing both By columns and rows:
data5=data.loc[5:10,['Loan_ID', 'Gender', 'Education']]
data5
# Out:
#      Loan_ID  Gender     Education
# 5   LP001054    Male  Not Graduate
# 6   LP001055  Female  Not Graduate
# 7   LP001056    Male  Not Graduate
# 8   LP001059    Male      Graduate
# 9   LP001067    Male  Not Graduate
# 10  LP001078    Male  Not Graduate
